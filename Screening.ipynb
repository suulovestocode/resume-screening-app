# %%
import numpy as np 
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("C:\Users\DELL\Desktop\ml project\UpdatedResumeDataSet.csv")
# Out:
#   Cell In[82], line 1
#     df=pd.read_csv("C:\Users\DELL\Desktop\ml project\UpdatedResumeDataSet.csv")
#                    ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape

# %%
df = pd.read_csv(r"C:\Users\DELL\Desktop\ml project\UpdatedResumeDataSet.csv")

# %%
df = pd.read_csv(r"C:\Users\DELL\Desktop\ml project\UpdatedResumeDataSet.csv")

# %%
df.head()
# Out:
#        Category                                             Resume
# 0  Data Science  Skills * Programming Languages: Python (pandas...
# 1  Data Science  Education Details \r\nMay 2013 to May 2017 B.E...
# 2  Data Science  Areas of Interest Deep Learning, Control Syste...
# 3  Data Science  Skills â¢ R â¢ Python â¢ SAP HANA â¢ Table...
# 4  Data Science  Education Details \r\n MCA   YMCAUST,  Faridab...

# %%
df.shape
# Out:
# (962, 2)

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the dataset
df = pd.read_csv(r"C:\Users\DELL\Desktop\ml project\UpdatedResumeDataSet.csv")

# Example: Assuming the dataset has 'Category' and 'Count' columns
# Modify according to your dataset structure
df['Category'].value_counts().plot(kind='bar', figsize=(10, 5), color='skyblue')

# Customize the graph
plt.xlabel("Categories")
plt.ylabel("Count")
plt.title("Distribution of Categories in Resume Dataset")
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.7)

# Show the plot
plt.show()

# %%
df['Category'].unique()
# Out:
# array(['Data Science', 'HR', 'Advocate', 'Arts', 'Web Designing',
#        'Mechanical Engineer', 'Sales', 'Health and fitness',
#        'Civil Engineer', 'Java Developer', 'Business Analyst',
#        'SAP Developer', 'Automation Testing', 'Electrical Engineering',
#        'Operations Manager', 'Python Developer', 'DevOps Engineer',
#        'Network Security Engineer', 'PMO', 'Database', 'Hadoop',
#        'ETL Developer', 'DotNet Developer', 'Blockchain', 'Testing'],
#       dtype=object)

# %%
import re 

def cleanResume(txt): 
    cleanText = re.sub(r'http\S+\s', '', txt)  # Remove URLs
    cleanText = re.sub(r'RT|CC', '', cleanText)  # Remove retweets and CC
    cleanText = re.sub(r'#\S+', '', cleanText)  # Remove hashtags
    cleanText = re.sub(r'@\S+', '', cleanText)  # Remove mentions
    cleanText = re.sub(r'[%s]' % re.escape('""#$%&*()*+,/:;<>?@[]^_`{|}~'), '', cleanText)  # Remove special characters
    cleanText = re.sub(r'[^\x00-\x7F]+', '', cleanText)  # Remove non-ASCII characters
    cleanText = re.sub(r'\s+', ' ', cleanText).strip()  # Remove extra spaces

    return cleanText

# %%
resume_text = "RT @user123: Check out this job post! http://example.com #Hiring []"
cleaned_text = cleanResume(resume_text)
print(cleaned_text)
# Out:
# Check out this job post!

# %%
df['Resume'] = df['Resume'].apply(lambda x: cleanResume(x))

# %%
print(df)
# Out:
#          Category                                             Resume
# 0    Data Science  Skills Programming Languages Python pandas num...
# 1    Data Science  Education Details May 2013 to May 2017 B.E UIT...
# 2    Data Science  Areas of Interest Deep Learning Control System...
# 3    Data Science  Skills R Python SAP HANA Tableau SAP HANA SQL ...
# 4    Data Science  Education Details MCA YMCAUST Faridabad Haryan...
# ..            ...                                                ...
# 957       Testing  Computer Skills Proficient in MS office Word B...
# 958       Testing  Willingness to accept the challenges. Positive...
# 959       Testing  PERSONAL SKILLS Quick learner Eagerness to lea...
# 960       Testing  COMPUTER SKILLS SOFTWARE KNOWLEDGE MS-Power Po...
# 961       Testing  Skill Set OS Windows XP788.110 Database MYSQL ...
#
# [962 rows x 2 columns]

# %%
import re 

def cleanResume(txt): 
    cleanText = re.sub(r'http\S+\s', '', txt)  # Remove URLs
    cleanText = re.sub(r'RT|CC', '', cleanText)  # Remove retweets and CC
    cleanText = re.sub(r'#\S+', '', cleanText)  # Remove hashtags
    cleanText = re.sub(r'@\S+', '', cleanText)  # Remove mentions
    cleanText = re.sub(r'[%s]' % re.escape('""#$%&*.()*+,./:;<>?@[]^_`{|}~'), '', cleanText)  # Remove special characters
    cleanText = re.sub(r'[^\x00-\x7F]+', '', cleanText)  # Remove non-ASCII characters
    cleanText = re.sub(r'\s+', ' ', cleanText).strip()  # Remove extra spaces

    return cleanText

# %%
df['Resume'] = df['Resume'].apply(lambda x: cleanResume(x))

# %%
print(df)
# Out:
#          Category                                             Resume
# 0    Data Science  Skills Programming Languages Python pandas num...
# 1    Data Science  Education Details May 2013 to May 2017 BE UIT-...
# 2    Data Science  Areas of Interest Deep Learning Control System...
# 3    Data Science  Skills R Python SAP HANA Tableau SAP HANA SQL ...
# 4    Data Science  Education Details MCA YMCAUST Faridabad Haryan...
# ..            ...                                                ...
# 957       Testing  Computer Skills Proficient in MS office Word B...
# 958       Testing  Willingness to accept the challenges Positive ...
# 959       Testing  PERSONAL SKILLS Quick learner Eagerness to lea...
# 960       Testing  COMPUTER SKILLS SOFTWARE KNOWLEDGE MS-Power Po...
# 961       Testing  Skill Set OS Windows XP788110 Database MYSQL s...
#
# [962 rows x 2 columns]

# %%
from sklearn.preprocessing import LabelEncoder 
le=LabelEncoder()

# %%
le.fit(df['Category'])
df['Category']=le.transform(df['Category'])

# %%
print(df['Category'])
# Out:
# 0       6
# 1       6
# 2       6
# 3       6
# 4       6
#        ..
# 957    23
# 958    23
# 959    23
# 960    23
# 961    23
# Name: Category, Length: 962, dtype: int64

# %%
df.Category.unique()
# Out:
# array([ 6, 12,  0,  1, 24, 16, 22, 14,  5, 15,  4, 21,  2, 11, 18, 20,  8,
#        17, 19,  7, 13, 10,  9,  3, 23])

# %%
df.Category.unique()
# Out:
# array([ 6, 12,  0,  1, 24, 16, 22, 14,  5, 15,  4, 21,  2, 11, 18, 20,  8,
#        17, 19,  7, 13, 10,  9,  3, 23])

# %%
df['Resume'] = df['Resume'].apply(lambda x: cleanResume(x))

# %%
df['Resume'][0]
# Out:
# 'Skills Programming Languages Python pandas numpy scipy scikit-learn matplotlib Sql Java JavaScriptJQuery Machine learning Regression SVM Nave Bayes KNN Random Forest Decision Trees Boosting techniques Cluster Analysis Word Embedding Sentiment Analysis Natural Language processing Dimensionality reduction Topic Modelling LDA NMF PCA Neural Nets Database Visualizations Mysql SqlServer Cassandra Hbase ElasticSearch D3js DCjs Plotly kibana matplotlib ggplot Tableau Others Regular Expression HTML CSS Angular 6 Logstash Kafka Python Flask Git Docker computer vision - Open CV and understanding of Deep learningEducation Details Data Science Assurance Associate Data Science Assurance Associate - Ernst Young LLP Skill Details JAVASCRIPT- Exprience - 24 months jQuery- Exprience - 24 months Python- Exprience - 24 monthsCompany Details company - Ernst Young LLP description - Fraud Investigations and Dispute Services Assurance TECHNOLOGY ASSISTED REVIEW TAR Technology Assisted Review assists in ac
# ...

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()

# %%
le.fit(df['Category'])
df['Category']=le.transform(df['Category'])

# %%
df.Category
# Out:
# 0       6
# 1       6
# 2       6
# 3       6
# 4       6
#        ..
# 957    23
# 958    23
# 959    23
# 960    23
# 961    23
# Name: Category, Length: 962, dtype: int64

# %%
df.Category.unique()
# Out:
# array([ 6, 12,  0,  1, 24, 16, 22, 14,  5, 15,  4, 21,  2, 11, 18, 20,  8,
#        17, 19,  7, 13, 10,  9,  3, 23])

# %%
df['Resume'][0]
# Out:
# 'Skills Programming Languages Python pandas numpy scipy scikit-learn matplotlib Sql Java JavaScriptJQuery Machine learning Regression SVM Nave Bayes KNN Random Forest Decision Trees Boosting techniques Cluster Analysis Word Embedding Sentiment Analysis Natural Language processing Dimensionality reduction Topic Modelling LDA NMF PCA Neural Nets Database Visualizations Mysql SqlServer Cassandra Hbase ElasticSearch D3js DCjs Plotly kibana matplotlib ggplot Tableau Others Regular Expression HTML CSS Angular 6 Logstash Kafka Python Flask Git Docker computer vision - Open CV and understanding of Deep learningEducation Details Data Science Assurance Associate Data Science Assurance Associate - Ernst Young LLP Skill Details JAVASCRIPT- Exprience - 24 months jQuery- Exprience - 24 months Python- Exprience - 24 monthsCompany Details company - Ernst Young LLP description - Fraud Investigations and Dispute Services Assurance TECHNOLOGY ASSISTED REVIEW TAR Technology Assisted Review assists in ac
# ...

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
tfidf=TfidVectorizer(stop_words='english')

tfidf.fit(df['Resume'])
requiredText=tfidf.transform(df['Resume'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[73], line 2
#       1 from sklearn.feature_extraction.text import TfidfVectorizer
# ----> 2 tfidf=TfidVectorizer(stop_words='english')
#       4 tfidf.fit(df['Resume'])
#       5 requiredText=tfidf.transform(df['Resume'])
#
# NameError: name 'TfidVectorizer' is not defined

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# Initialize TfidfVectorizer
tfidf = TfidfVectorizer(stop_words='english')

# Fit and transform the 'Resume' column
tfidf.fit(df['Resume'])
requiredText = tfidf.transform(df['Resume'])

# %%
df
# Out:
#      Category                                             Resume
# 0           6  Skills Programming Languages Python pandas num...
# 1           6  Education Details May 2013 to May 2017 BE UIT-...
# 2           6  Areas of Interest Deep Learning Control System...
# 3           6  Skills R Python SAP HANA Tableau SAP HANA SQL ...
# 4           6  Education Details MCA YMCAUST Faridabad Haryan...
# ..        ...                                                ...
# 957        23  Computer Skills Proficient in MS office Word B...
# 958        23  Willingness to accept the challenges Positive ...
# 959        23  PERSONAL SKILLS Quick learner Eagerness to lea...
# 960        23  COMPUTER SKILLS SOFTWARE KNOWLEDGE MS-Power Po...
# 961        23  Skill Set OS Windows XP788110 Database MYSQL s...
#
# [962 rows x 2 columns]

# %%
requiredText
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'float64'
# 	with 164481 stored elements and shape (962, 7697)>

# %%
from sklearn.model_selection import train_test_split

# Assuming 'Category' is the target column
y = df['Category']  # Define the target variable

# Split the data
x_train, x_test, y_train, y_test = train_test_split(requiredText, y, test_size=0.2, random_state=42)

# %%
x_train.shape
# Out:
# (769, 7697)

# %%
x_test.shape
# Out:
# (193, 7697)

# %% [markdown]
# # Now lets train the model and print the classification report:

# %%
from sklearn.neighbours import KNeighboursClassifier
from sklearn.mulitclass import OneVsRestClassifier
clf= OneVsRestClassifier(KNeighrborsClassifier())
clf.fit(x_train,y_train)
ypred=clf.predict(x_test)
print(yred)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[119], line 1
# ----> 1 from sklearn.neighbours import KNeighboursClassifier
#       2 from sklearn.mulitclass import OneVsRestClassifier
#       3 clf= OneVsRestClassifier(KNeighrborsClassifier())
#
# ModuleNotFoundError: No module named 'sklearn.neighbours'

# %%
from sklearn.neighbors import KNeighborsClassifier  # Corrected import
from sklearn.multiclass import OneVsRestClassifier  # Corrected import

# Initialize OneVsRestClassifier with KNeighborsClassifier
clf = OneVsRestClassifier(KNeighborsClassifier())  # Corrected class name

# Fit the model
clf.fit(x_train, y_train)

# Predict on test data
y_pred = clf.predict(x_test)  # Corrected variable name

# Print predictions
print(y_pred)  # Corrected variable name
# Out:
# [15 15 15 13 14 17 16  2  0 14 13 12 16 23 20  5  6  4 10  9 19  1 10 23
#  23 21 22 22  2 12 18  1  8 24 11 23  7 12 24  8 18  6  8 19 24 23 21  1
#  15  4 15 22 11  5 15 13  1 19  5 12 22 22 20 24 21 18 12 10 10 20 10  8
#   9 21 17 21  0 17 16 14 15 11 11  8 20  3 19  8  0  2  9 10  2 23 20 20
#  23 12 18 12  7 16  8 14 18  3 14 19 14 14 15 18  8  2 21 18 23 10 23  5
#  11 15 12  3  5  3  7 12 19  8 20 19  3 15  9 19  1 23 21  5 20 15 16  7
#   7  8 15 18  1 15 13 20  7  4 18 11  5 15  5 12  9 22 18 21  8 23  4 12
#  24 16 15 22  8 22  3 16 23 23 12  7 16 18  5  3 18  8 23 23 20 21  6  7
#  23]

# %%
from sklearn.metrics import accuracy_score

# Calculate accuracy
accuracy = accuracy_score(y_test, y_pred)

# Print accuracy
print(f"Accuracy: {accuracy:.4f}")
# Out:
# Accuracy: 0.9845

# %% [markdown]
# # Prediction System

# %%
myresume="""Dedicated and analytical Data Science student with a strong foundation in Machine Learning, Data Analysis, and Statistical Modeling. Proficient in Python, SQL, and libraries such as Pandas, NumPy, Scikit-Learn, and TensorFlow. Experienced in building predictive models, performing data visualization using Matplotlib and Seaborn, and working with large datasets to extract actionable insights. Skilled in Natural Language Processing (NLP) and exploratory data analysis (EDA). Passionate about solving real-world problems through data-driven decision-making and optimizing business processes. Seeking opportunities to apply my technical skills in a data-centric role to drive meaningful impact."""

# %%
import pickle

pickle.dump(tfidf, open('tfidf.pkl', 'wb'))  # Fixed missing parenthesis and incorrect variable name
pickle.dump(clf, open('clf.pkl', 'wb'))  # Fixed misspelled 'pinckle' and missing quotes around filename

# %%
import pickle

clf = pickle.load(open('clf.pkl', 'rb'))  # Fixed missing closing parenthesis

cleaned_resume = cleanResume(myresume)
input_features = tfidfd.transform([cleaned_resume])
prediction_id = clf.predict(input_features)[0]

category_mapping = {
    0: "Advocate",
    1: "Arts",
    2: "Automation Testing",
    3: "Blockchain",
    4: "Business Analyst",
    5: "Civil Engineer",
    6: "Data Science",
    7: "Database",
    8: "DevOps Engineer",
    9: "DotNet Developer",
    10: "ETL Developer",
    11: "Electrical Engineering",
    12: "HR",
    13: "Hadoop",
    14: "Health and Fitness",
    15: "Java Developer",
    16: "Mechanical Engineer",
    17: "Network Security Engineer",
    18: "Operations Manager",
    19: "PMO",
    20: "Python Developer",
    21: "SAP Developer",
    22: "Sales",
    23: "Testing",
    24: "Web Designing"
}

# Example: Convert category numbers in df['Category'] to actual labels
category_name = category_mapping.get(prediction_id, "unknown")  # Fixed typo 'categor.mapping' → 'category_mapping'
print(prediction_id)
print("Predicted Category:", category_name)  # Fixed typo 'Pedicted Categort' → 'Predicted Category'
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[116], line 6
#       3 clf = pickle.load(open('clf.pkl', 'rb'))  # Fixed missing closing parenthesis
#       5 cleaned_resume = cleanResume(myresume)
# ----> 6 input_features = tfidfd.transform([cleaned_resume])
#       7 prediction_id = clf.predict(input_features)[0]
#       9 category_mapping = {
#      10     0: "Advocate",
#      11     1: "Arts",
#    (...)
#      34     24: "Web Designing"
#      35 }
#
# NameError: name 'tfidfd' is not defined

# %%
import pickle

clf = pickle.load(open('clf.pkl', 'rb'))  # Fixed missing closing parenthesis

cleaned_resume = cleanResume(myresume)
input_features = tfidf.transform([cleaned_resume])  # Fixed 'tfidfd' → 'tfidf'
prediction_id = clf.predict(input_features)[0]

category_mapping = {
    0: "Advocate",
    1: "Arts",
    2: "Automation Testing",
    3: "Blockchain",
    4: "Business Analyst",
    5: "Civil Engineer",
    6: "Data Science",
    7: "Database",
    8: "DevOps Engineer",
    9: "DotNet Developer",
    10: "ETL Developer",
    11: "Electrical Engineering",
    12: "HR",
    13: "Hadoop",
    14: "Health and Fitness",
    15: "Java Developer",
    16: "Mechanical Engineer",
    17: "Network Security Engineer",
    18: "Operations Manager",
    19: "PMO",
    20: "Python Developer",
    21: "SAP Developer",
    22: "Sales",
    23: "Testing",
    24: "Web Designing"
}

# Example: Convert category numbers in df['Category'] to actual labels
category_name = category_mapping.get(prediction_id, "unknown")  # Fixed incorrect reference
print(prediction_id)
print("Predicted Category:", category_name)  # Fixed typo in print statement
# Out:
# 6
# Predicted Category: Data Science

# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder
import pickle

# Load dataset (Use a double backslash `\\` or raw string `r""` to avoid path errors)
df = pd.read_csv(r"C:\Users\DELL\Desktop\ml project\UpdatedResumeDataSet.csv")

# Assuming the category column is named 'Category' in your dataset
labels = df['Category']

# Initialize and fit LabelEncoder
le = LabelEncoder()
labels_encoded = le.fit_transform(labels)

# Save LabelEncoder for later use
with open(r"C:\Users\DELL\Desktop\ml project\encoder.pkl", 'wb') as file:
    pickle.dump(le, file)

print("encoder.pkl file created successfully at:", r"C:\Users\DELL\Desktop\ml project\encoder.pkl")
# Out:
# encoder.pkl file created successfully at: C:\Users\DELL\Desktop\ml project\encoder.pkl
